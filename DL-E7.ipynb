# %% [markdown]
# https://www.kaggle.com/datasets/szrlee/stock-time-series-20050101-to-20171231?resource=download&select=AMZN_2006-01-01_to_2018-01-01.csv

# %% [markdown]
# ## RNN using LSTM & GRU

# %%
# !wget "https://storage.googleapis.com/kagglesdsdata/datasets/8388/11883/AMZN_2006-01-01_to_2018-01-01.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240929%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240929T171214Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."
# !mv AMZN* AMZN.csv
# Out:
# The destination name is too long (789), reducing to 236
# --2024-09-29 17:14:37--  https://storage.googleapis.com/kagglesdsdata/datasets/8388/11883/AMZN_2006-01-01_to_2018-01-01.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240929%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240929T171214Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.99.207, 142.250.107.207, 74.125.20.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.99.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 154394 (151K) [application/vnd.ms-excel]
# Saving to: ‘AMZN_2006-01-01_to_2018-01-01.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com@kaggle-161607.iam.gserviceaccount.com%2F20240929%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240929T171214Z&X-Goog-Expires=259200&X-’
#
# ...

# %%
# !wget "https://storage.googleapis.com/kagglesdsdata/datasets/8388/11883/IBM_2006-01-01_to_2018-01-01.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240929%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240929T172412Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."
# !mv IBM* IBM.csv
# Out:
# The destination name is too long (788), reducing to 236
# --2024-09-29 17:24:41--  https://storage.googleapis.com/kagglesdsdata/datasets/8388/11883/IBM_2006-01-01_to_2018-01-01.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240929%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240929T172412Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.107.207, 74.125.20.207, 108.177.98.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.107.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 153466 (150K) [application/vnd.ms-excel]
# Saving to: ‘IBM_2006-01-01_to_2018-01-01.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com@kaggle-161607.iam.gserviceaccount.com%2F20240929%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240929T172412Z&X-Goog-Expires=259200&X-G’
#
# ...

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

# %%
# Some functions to help out with
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real IBM Stock Price')
    plt.plot(predicted, color='blue',label='Predicted IBM Stock Price')
    plt.title('IBM Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('IBM Stock Price')
    plt.legend()
    plt.show()

def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %%
dataset = pd.read_csv('/content/IBM.csv', index_col='Date', parse_dates=['Date'])
dataset.head()
# Out:
#              Open   High    Low  Close    Volume Name
# Date
# 2006-01-03  82.45  82.55  80.81  82.06  11715200  IBM
# 2006-01-04  82.20  82.50  81.33  81.95   9840600  IBM
# 2006-01-05  81.40  82.90  81.00  82.50   7213500  IBM
# 2006-01-06  83.95  85.03  83.41  84.95   8197400  IBM
# 2006-01-09  84.10  84.25  83.38  83.73   6858200  IBM

# %%
# Checking for missing values
training_set = dataset[:'2016'].iloc[:,1:2].values
test_set = dataset['2017':].iloc[:,1:2].values

# %%
# Scaling the training set
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# Since LSTMs store long term memory state, we create a data structure with 60 timesteps and 1 output
# So for each element of training set, we have 60 previous training set elements
X_train = []
y_train = []
for i in range(60,2769):
    X_train.append(training_set_scaled[i-60:i,0])
    y_train.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# Reshaping X_train for efficient modelling
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))

# %%
regressor = Sequential()
# First  layer with Dropout regularisation
regressor.add((units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0.2))
# Second  layer
regressor.add((units=50, return_sequences=True))
regressor.add(Dropout(0.2))
# Third  layer
regressor.add((units=50, return_sequences=True))
regressor.add(Dropout(0.2))
# Fourth  layer
regressor.add((units=50))
regressor.add(Dropout(0.2))
# The output layer
regressor.add(Dense(units=1))

# Compiling the RNN
regressor.compile(optimizer='rmsprop',loss='mean_squared_error')
# Fitting to the training set
regressor.fit(X_train,y_train,epochs=50,batch_size=32)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0417
# Epoch 2/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0106
# Epoch 3/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0080
# Epoch 4/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0079
# Epoch 5/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0065
# Epoch 6/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0058
# Epoch 7/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0050
# Epoch 8/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0043
# Epoch 9/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0037
# Epoch 10/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0048
# ...

# %%
dataset_total = pd.concat((dataset["High"][:'2016'],dataset["High"]['2017':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# Preparing X_test and predicting the prices
X_test = []
for i in range(60,311):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# Visualizing the results for LSTM
plot_predictions(test_set,predicted_stock_price)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step

# %%
# Evaluating our model
return_rmse(test_set,predicted_stock_price)
# Out:
# The root mean squared error is 3.0157023243230916.
