# %% [markdown]
# # Binary Classification RNN

# %%
# !ls
# Out:
# sample_data

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Input, Embedding, LSTM, GlobalMaxPooling1D, Dense
from tensorflow.keras.models import Model

from sklearn import metrics
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/spam.csv',encoding='latin-1')

# %%
# convert labels to binary numbers
df['class'] = df['v1'].map({'ham': 0, 'spam': 1})
Y = df['class'].values
df_train, df_test, Ytrain, Ytest = train_test_split(df['v2'], Y, test_size=0.2)

# %%
# Convert string into vector of integers
MAX_VOCAB_SIZE = 20000
MAX_SEQUENCE_SIZE = 160

tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE)
tokenizer.fit_on_texts(df_train)
sequences_train = tokenizer.texts_to_sequences(df_train)
sequences_test = tokenizer.texts_to_sequences(df_test)

# pad the sequences so each vector in the matrix has same length
data_train = pad_sequences(sequences_train, maxlen=MAX_SEQUENCE_SIZE)
data_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_SIZE)

print('Shape of data train tensor:', data_train.shape)
print('Shape of data test tensor:', data_test.shape)
# Out:
# Shape of data train tensor: (4457, 160)
# Shape of data test tensor: (1115, 160)

# %%
# Create the model

x = Input(shape=(data_train.shape[1],))
y = Embedding(len(tokenizer.word_index) + 1, 20)(x)
y = LSTM(15, return_sequences=True)(y)
y = GlobalMaxPooling1D()(y)
y = Dense(1, activation='sigmoid')(y)

model = Model(inputs=x, outputs=y)

# %%
# Compile and fit
model.compile(
  loss='binary_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

fitted_model = model.fit(
  x=data_train,
  y=Ytrain,
  epochs=30,
  validation_split=0.2,
)
# Out:
# Epoch 1/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9997 - loss: 0.0050 - val_accuracy: 0.9888 - val_loss: 0.0540
# Epoch 2/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9989 - loss: 0.0054 - val_accuracy: 0.9899 - val_loss: 0.0546
# Epoch 3/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9998 - loss: 0.0027 - val_accuracy: 0.9888 - val_loss: 0.0576
# Epoch 4/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9999 - loss: 0.0016 - val_accuracy: 0.9877 - val_loss: 0.0615
# Epoch 5/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9996 - loss: 0.0028 - val_accuracy: 0.9877 - val_loss: 0.0656
# Epoch 6/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9997 - loss: 0.0021 - val_accuracy: 0.9877 - val_loss: 0.0692
# Epoch 7/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9999 - loss: 9.2960e-04 - val_accuracy: 0.9877 - val_loss: 0.0719
# Epoch 8/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9999 - loss: 8.3814e-04 - val_accuracy: 0.9865 - val_loss: 0.0748
# Epoch 9/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9995 - loss: 0.0019 - val_accuracy: 0.9854 - val_loss: 0.0788
# Epoch 10/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9998 - loss: 9.0833e-04 - val_accuracy: 0.9843 - val_loss: 0.0839
# Epoch 11/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.9843 - val_loss: 0.0888
# Epoch 12/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 4.0214e-04 - val_accuracy: 0.9843 - val_loss: 0.0923
# Epoch 13/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9997 - loss: 6.8927e-04 - val_accuracy: 0.9832 - val_loss: 0.0980
# Epoch 14/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9995 - loss: 7.3277e-04 - val_accuracy: 0.9832 - val_loss: 0.0998
# Epoch 15/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 4.9896e-04 - val_accuracy: 0.9832 - val_loss: 0.1018
# Epoch 16/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 3.3168e-04 - val_accuracy: 0.9843 - val_loss: 0.1032
# Epoch 17/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 4.6151e-04 - val_accuracy: 0.9832 - val_loss: 0.1031
# Epoch 18/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.4505e-04 - val_accuracy: 0.9821 - val_loss: 0.1043
# Epoch 19/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.0104e-04 - val_accuracy: 0.9821 - val_loss: 0.1051
# Epoch 20/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 3.7248e-04 - val_accuracy: 0.9832 - val_loss: 0.1062
# Epoch 21/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.7460e-04 - val_accuracy: 0.9832 - val_loss: 0.1077
# Epoch 22/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.1689e-04 - val_accuracy: 0.9832 - val_loss: 0.1088
# Epoch 23/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.1291e-04 - val_accuracy: 0.9832 - val_loss: 0.1118
# Epoch 24/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 1.1882e-04 - val_accuracy: 0.9832 - val_loss: 0.1138
# Epoch 25/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 1.0000 - loss: 1.1518e-04 - val_accuracy: 0.9832 - val_loss: 0.1159
# Epoch 26/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 8.1488e-05 - val_accuracy: 0.9821 - val_loss: 0.1174
# Epoch 27/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 8.1445e-05 - val_accuracy: 0.9821 - val_loss: 0.1191
# Epoch 28/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 7.0414e-05 - val_accuracy: 0.9821 - val_loss: 0.1209
# Epoch 29/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 6.5131e-05 - val_accuracy: 0.9821 - val_loss: 0.1230
# Epoch 30/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 7.4536e-05 - val_accuracy: 0.9821 - val_loss: 0.1247

# %%
Ypreds = (model.predict(data_test) > 0.5).astype("int32")
print('Model Accuracy score:', metrics.accuracy_score(Ytest, Ypreds))
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Model Accuracy score: 0.9838565022421525
