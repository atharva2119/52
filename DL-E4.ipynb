# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from keras.datasets import fashion_mnist

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

x_train1 = x_train/255
x_test1 = x_test/255

# %%
m_classifier = Sequential()
m_classifier.add(Conv2D(32,(3,3),activation='relu', input_shape=(28,28,1)))
m_classifier.add(MaxPooling2D(pool_size=(2,2)))
m_classifier.add(Conv2D(64,(3,3),activation='relu',))
m_classifier.add(MaxPooling2D(pool_size=(2,2)))
m_classifier.add(Flatten())
m_classifier.add(Dense(250,activation='relu'))
m_classifier.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
m_classifier.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

m_classifier.fit(x_train1,y_train,batch_size=50,epochs=30,validation_data=(x_test1,y_test))
# Out:
# Epoch 1/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9145 - loss: 0.2307 - val_accuracy: 0.8993 - val_loss: 0.2708
# Epoch 2/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9243 - loss: 0.2034 - val_accuracy: 0.9026 - val_loss: 0.2635
# Epoch 3/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9338 - loss: 0.1795 - val_accuracy: 0.9014 - val_loss: 0.2721
# Epoch 4/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9395 - loss: 0.1595 - val_accuracy: 0.9117 - val_loss: 0.2602
# Epoch 5/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9471 - loss: 0.1408 - val_accuracy: 0.9062 - val_loss: 0.2816
# Epoch 6/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9549 - loss: 0.1205 - val_accuracy: 0.9052 - val_loss: 0.2790
# Epoch 7/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9589 - loss: 0.1080 - val_accuracy: 0.9138 - val_loss: 0.2904
# Epoch 8/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9666 - loss: 0.0903 - val_accuracy: 0.9096 - val_loss: 0.3074
# Epoch 9/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9702 - loss: 0.0820 - val_accuracy: 0.9103 - val_loss: 0.3153
# Epoch 10/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9753 - loss: 0.0672 - val_accuracy: 0.9154 - val_loss: 0.3239
# Epoch 11/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9789 - loss: 0.0579 - val_accuracy: 0.9031 - val_loss: 0.3770
# Epoch 12/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9792 - loss: 0.0563 - val_accuracy: 0.9062 - val_loss: 0.3998
# Epoch 13/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9827 - loss: 0.0459 - val_accuracy: 0.9145 - val_loss: 0.3911
# Epoch 14/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9867 - loss: 0.0377 - val_accuracy: 0.9110 - val_loss: 0.4122
# Epoch 15/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9872 - loss: 0.0355 - val_accuracy: 0.9079 - val_loss: 0.4332
# Epoch 16/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9863 - loss: 0.0358 - val_accuracy: 0.9129 - val_loss: 0.4635
# Epoch 17/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9882 - loss: 0.0321 - val_accuracy: 0.9140 - val_loss: 0.4575
# Epoch 18/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9911 - loss: 0.0246 - val_accuracy: 0.9119 - val_loss: 0.4614
# Epoch 19/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9910 - loss: 0.0255 - val_accuracy: 0.9114 - val_loss: 0.4868
# Epoch 20/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9915 - loss: 0.0218 - val_accuracy: 0.9126 - val_loss: 0.5512
# Epoch 21/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9919 - loss: 0.0232 - val_accuracy: 0.9104 - val_loss: 0.5778
# Epoch 22/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9920 - loss: 0.0228 - val_accuracy: 0.9115 - val_loss: 0.5571
# Epoch 23/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9936 - loss: 0.0177 - val_accuracy: 0.9064 - val_loss: 0.5738
# Epoch 24/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9946 - loss: 0.0152 - val_accuracy: 0.9111 - val_loss: 0.6123
# Epoch 25/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9929 - loss: 0.0209 - val_accuracy: 0.9095 - val_loss: 0.5992
# Epoch 26/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9938 - loss: 0.0187 - val_accuracy: 0.9063 - val_loss: 0.6538
# Epoch 27/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9923 - loss: 0.0216 - val_accuracy: 0.9083 - val_loss: 0.6050
# Epoch 28/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9957 - loss: 0.0131 - val_accuracy: 0.9129 - val_loss: 0.6516
# Epoch 29/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9931 - loss: 0.0199 - val_accuracy: 0.9129 - val_loss: 0.6211
# Epoch 30/30
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9945 - loss: 0.0177 - val_accuracy: 0.9066 - val_loss: 0.6479

# %%
m_classifier.evaluate(x_test1,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9014 - loss: 0.6990
# [0.6478553414344788, 0.9065999984741211]
